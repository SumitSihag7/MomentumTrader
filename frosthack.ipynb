# %%
# %matplotlib inline
from momentum_strategy import run_all_backtests

datasets = {
    "Apple": "dataset/Apple_stock_data.csv",
    "Facebook": "dataset/Facebook_stock_data.csv",
    "Tesla": "dataset/Tesla_stock_data.csv",
    "JP Morgan": "dataset/JP Morgan_stock_data.csv",
    "Amazon": "dataset/Amazon_stock_data.csv"
}

# Run the backtests and generate plots
run_all_backtests(datasets, plot=True)
# Out:
# Performance of Apple (MA 10/50, RSI 14):
# Total Return (Market):     935.85%
# Total Return (Strategy):   218.59%
# Annualized Return (Market):   26.99%
# Annualized Return (Strategy): 12.57%
# Maximum Drawdown (Market):    -38.52%
# Maximum Drawdown (Strategy):  -22.46%
# ------------------------------------------------------------
# Performance of Facebook (MA 10/50, RSI 14):
# Total Return (Market):     656.53%
# Total Return (Strategy):   542.20%
# Annualized Return (Market):   22.97%
# Annualized Return (Strategy): 20.93%
# Maximum Drawdown (Market):    -76.74%
# Maximum Drawdown (Strategy):  -44.21%
# ------------------------------------------------------------
# Performance of Tesla (MA 10/50, RSI 14):
# Total Return (Market):     2754.93%
# Total Return (Strategy):   71.99%
# Annualized Return (Market):   40.85%
# Annualized Return (Strategy): 5.70%
# Maximum Drawdown (Market):    -73.63%
# Maximum Drawdown (Strategy):  -55.12%
# ...
